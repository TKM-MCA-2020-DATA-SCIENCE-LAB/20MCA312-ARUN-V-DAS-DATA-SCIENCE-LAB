# %% [markdown]
# #**<center><u>CO5</center>**

# %% [markdown]
# #**<center><u>PROGRAM : 1 </center>**
# **AIM:</u>**
#
# Implement a simple web crawler (ensure ethical conduct).

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

# %%
html= urlopen('https://en.wikipedia.org/wiki/Web_crawler')
bs =BeautifulSoup(html,'html.parser')
for link in bs.find('div',{'id':'bodyContent'}).find_all('a',href=re.compile('^(/wiki/)((?!:).)*$')):
  if 'href' in link.attrs:
    print(link.attrs['href'])
# Out:
# /wiki/WebCrawler
# /wiki/Spider_web
# /wiki/Arac_(video_game)
# /wiki/Internet_bot
# /wiki/World_Wide_Web
# /wiki/Web_indexing
# /wiki/Web_search_engine
# /wiki/Website
# /wiki/Software
# /wiki/Web_content
# /wiki/Index_(search_engine)
# /wiki/Robots.txt
# /wiki/Software_agent
# /wiki/Hyperlink
# /wiki/HTML
# /wiki/Web_scraping
# /wiki/Data-driven_programming
# /wiki/FOAF_(software)
# /wiki/Uniform_Resource_Locator
# /wiki/Web_server
# /wiki/Hyperlink
# /wiki/Crawl_frontier
# /wiki/Recursion
# /wiki/Website
# /wiki/Web_archiving
# /wiki/Web_page
# /wiki/Repository_(version_control)
# /wiki/HTML
# /wiki/Duplicate_content
# /wiki/HTTP
# /wiki/HTTP
# /wiki/Thumbnail
# /wiki/Mathematical_combination
# /wiki/Bandwidth_(computing)
# /wiki/Web_sites
# /wiki/Search_engines
# /wiki/Steve_Lawrence_(computer_scientist)
# /wiki/Lee_Giles
# /wiki/Search_engine_indexing
# /wiki/Web_pages
# /wiki/Intrinsic_and_extrinsic_properties_(philosophy)
# /wiki/Vertical_search
# /wiki/Top-level_domain
# /wiki/Breadth-first_search
# /wiki/Backlink
# /wiki/PageRank
# /wiki/Algorithm
# /wiki/Breadth-first_search
# /wiki/Internet_media_type
# /wiki/Query_string
# /wiki/Spider_trap
# /wiki/URL_rewriting
# /wiki/URL_normalization
# /wiki/URL_normalization
# /wiki/Focused_crawler
# /wiki/Filippo_Menczer
# /wiki/Focused_crawlers
# /wiki/CiteSeer
# /wiki/Google_Scholar
# /wiki/Microsoft_Academic_Search
# /wiki/PDF
# /wiki/PDF
# /wiki/PostScript
# /wiki/Microsoft_Word
# /wiki/Zipped_file
# /wiki/Heritrix
# /wiki/MIME_types
# /wiki/Middleware
# /wiki/Machine_learning
# /wiki/Regular_expression
# /wiki/HTML
# /wiki/Metadata
# /wiki/PDF
# /wiki/Domain_ontology
# /wiki/Edward_G._Coffman,_Jr.
# /wiki/Edward_G._Coffman,_Jr.
# /wiki/Panos_Ipeirotis
# /wiki/Robots_Exclusion_Standard
# /wiki/Google.com
# /wiki/Ask.com
# /wiki/Bing_(search_engine)
# /wiki/Yahoo!_Search
# /wiki/Robots.txt
# /wiki/Sergey_Brin
# /wiki/Larry_Page
# /wiki/Distributed_web_crawling
# /wiki/Parallel_computing
# /wiki/Spamdexing
# /wiki/Web_search_engine
# /wiki/Unintended_consequences
# /wiki/Web_application_security
# /wiki/Data_breach
# /wiki/Google_hacking
# /wiki/Web_application_security
# /wiki/Robots_exclusion_standard
# /wiki/User_agent
# /wiki/HTTP
# /wiki/Web_server
# /wiki/Uniform_Resource_Locator
# /wiki/Spambots
# /wiki/Spider_trap
# /wiki/Web_search_engine
# /wiki/Deep_Web_(search_indexing)
# /wiki/Sitemaps
# /wiki/Mod_oai
# /wiki/Googlebot
# /wiki/Screen_scraping
# /wiki/AJAX
# /wiki/List_of_search_engine_software
# /wiki/World_Wide_Web_Worm
# /wiki/Grep
# /wiki/Unix
# /wiki/Yahoo!
# /wiki/Microsoft
# /wiki/Bingbot
# /wiki/Apple_(company)
# /wiki/Siri
# /wiki/Bingbot
# /wiki/Bing_(search_engine)
# /wiki/Msnbot
# /wiki/Baidu
# /wiki/Googlebot
# /wiki/Python_(programming_language)
# /wiki/WebCrawler
# /wiki/Libwww
# /wiki/WebFountain
# /wiki/Xenon_(program)
# /wiki/SortSite
# /wiki/Microsoft_Windows
# /wiki/Macintosh_operating_systems
# /wiki/Swiftype
# /wiki/Software_as_a_service
# /wiki/Wget
# /wiki/Command_line_interface
# /wiki/C_(programming_language)
# /wiki/GNU_General_Public_License
# /wiki/Grub_(search_engine)
# /wiki/Wikia_Search
# /wiki/Heritrix
# /wiki/Internet_Archive
# /wiki/Java_(programming_language)
# /wiki/Ht-//dig
# /wiki/HTTrack
# /wiki/C_(programming_language)
# /wiki/GNU_General_Public_License
# /wiki/MnoGoSearch
# /wiki/GNU_General_Public_License
# /wiki/Apache_Nutch
# /wiki/Apache_License
# /wiki/Apache_Hadoop
# /wiki/Apache_Solr
# /wiki/Elasticsearch
# /wiki/Open_Search_Server
# /wiki/GNU_General_Public_License
# /wiki/PHP
# /wiki/MySQL
# /wiki/BSD_License
# /wiki/Scrapy
# /wiki/BSD_License
# /wiki/Seeks
# /wiki/GNU_Affero_General_Public_License
# /wiki/StormCrawler
# /wiki/Storm_(event_processor)
# /wiki/Apache_License
# /wiki/TkWWW_Robot
# /wiki/TkWWW
# /wiki/GNU_General_Public_License
# /wiki/Xapian
# /wiki/YaCy
# /wiki/GNU_General_Public_License
# /wiki/Automatic_indexing
# /wiki/Gnutella_crawler
# /wiki/Web_archiving
# /wiki/Webgraph
# /wiki/Website_mirroring_software
# /wiki/Search_Engine_Scraping
# /wiki/Web_scraping
# /wiki/National_Center_for_Supercomputing_Applications
# /wiki/CiteSeerX_(identifier)
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Wayback_Machine
# /wiki/ISBN_(identifier)
# /wiki/CiteSeerX_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/Bibcode_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMID_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/CiteSeerX_(identifier)
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Webist
# /wiki/Alexandra_Poulovassilis
# /wiki/ISBN_(identifier)
# /wiki/CiteSeerX_(identifier)
# /wiki/Doi_(identifier)
# /wiki/Doi_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/Hdl_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/CiteSeerX_(identifier)
# /wiki/Doi_(identifier)
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/CiteSeerX_(identifier)
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Wayback_Machine
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/Doi_(identifier)
# /wiki/Torsten_Suel
# /wiki/Wayback_Machine
# /wiki/ArXiv_(identifier)
# /wiki/Bibcode_(identifier)
# /wiki/Doi_(identifier)
# /wiki/Wired_(magazine)
# /wiki/John_Wiley_%26_Sons
# /wiki/OWASP
# /wiki/Internet_search
# /wiki/Web_search_engine
# /wiki/List_of_search_engines
# /wiki/Metasearch_engine
# /wiki/Multimedia_search
# /wiki/Collaborative_search_engine
# /wiki/Cross-language_search
# /wiki/Local_search_(Internet)
# /wiki/Vertical_search
# /wiki/Social_search
# /wiki/Image_retrieval
# /wiki/Audio_search_engine
# /wiki/Video_search_engine
# /wiki/Enterprise_search
# /wiki/Semantic_search
# /wiki/Natural_language_search_engine
# /wiki/Voice_search
# /wiki/Search_by_sound
# /wiki/Search_engine_marketing
# /wiki/Search_engine_optimization
# /wiki/Evaluation_measures_(information_retrieval)
# /wiki/Search_oriented_architecture
# /wiki/Selection-based_search
# /wiki/Document_retrieval
# /wiki/Text_mining
# /wiki/Multisearch
# /wiki/Federated_search
# /wiki/Search_aggregator
# /wiki/Index_(search_engine)
# /wiki/Web_indexing
# /wiki/Focused_crawler
# /wiki/Spider_trap
# /wiki/Robots_exclusion_standard
# /wiki/Distributed_web_crawling
# /wiki/Web_archiving
# /wiki/Website_mirroring_software
# /wiki/Web_query
# /wiki/Web_query_classification
# /wiki/Z39.50
# /wiki/Search/Retrieve_Web_Service
# /wiki/Search/Retrieve_via_URL
# /wiki/OpenSearch
# /wiki/Representational_State_Transfer
# /wiki/Wide_area_information_server
# /wiki/Search_engine_(computing)
# /wiki/Desktop_search
# /wiki/Online_search
# /wiki/Internet_bot
# /wiki/Web_crawling
# /wiki/Web_indexing
# /wiki/80legs
# /wiki/Bingbot
# /wiki/Fetcher
# /wiki/Googlebot
# /wiki/Heritrix
# /wiki/HTTrack
# /wiki/PowerMapper
# /wiki/Wget
# /wiki/FAST_Crawler
# /wiki/Msnbot
# /wiki/RBSE
# /wiki/TkWWW_robot
# /wiki/Twiceler
# /wiki/Distributed_web_crawler
# /wiki/Focused_crawler
